# %%
from main import simulate, processing_only

system_cfg_path = 'results/thruster_1_steady/cfg_files/thruster_1.cfg'
simulation_cfg_path = 'results/thruster_1_steady/cfg_files/simulation_thruster_steady.cfg'
processing_simulation_path = 'results/thruster_1_steady/cfg_files/processing_thruster_1_steady.cfg'

processing_only(system_cfg_path, simulation_cfg_path, processing_simulation_path, recompute = False)
#simulate(system_cfg_path, simulation_cfg_path, processing_simulation_path, load = -2) # recompute = True)
# Out:
# Creating data analyser from /home/paul/Documents/projects/Neutralisation_Faisceau_ions_negatifs_propulsion_satellite/results/thruster_1_steady/params.csv...	[OK]
# Loading test 1...Number of iterations : 2601
# 	[OK]
# 	Compute spatial distribution evolution...	[OK]
# 	Compute selected frames...	[OK]
# 	Collisions...
# For test 1, N_e = 0.000000e+00 vs N_t = 3.360000e+13.
# [END COLLISIONS]
# 	Compute density...	[OK]
# 	Compute number of particles evolution...	[OK]
