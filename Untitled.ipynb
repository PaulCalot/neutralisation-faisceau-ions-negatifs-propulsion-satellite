# %%
from main import simulate, processing_only
# square
system_cfg_path = ['cfg_files/thruster.cfg']
simulation_cfg_path = ['cfg_files/simulation_thruster.cfg']
processing_simulation_path = ['cfg_files/processing_thruster.cfg']

for system, simu, proc in zip(system_cfg_path, simulation_cfg_path, processing_simulation_path):
    simulate(system, simu, proc, verbose=True)
# Out:
# {'processing': {'compute_collisions': True,
#                 'compute_hist_distribution_evolution': False,
#                 'compute_spatial_distribution': False,
#                 'compute_system_evolution': True,
#                 'compute_temperature': True,
#                 'files_to_merge': ['1', '2'],
#                 'frames_to_compute': ['first', 'last'],
#                 'id_test': '1',
#                 'merge_csv': False,
#                 'path': PosixPath('/home/paul/Documents/projects/Neutralisation_Faisceau_ions_negatifs_propulsion_satellite/results/thruster_1'),
#                 'period': 5,
#                 'save': True,
#                 'saving_offset': 0},
#  'simulation': {'dt': 0.025,
#                 'number_of_steps': 500,
#                 'scheme': 'euler_explicit'},
#  'system': {'drifts': [50],
#             'flux_in_wall': 'top',
#             'flux_out_wall': 'bottom',
#             'general': {'lz': 0.001, 'resolution': [5, 14]},
#             'geometry': {'L_1': 0.002,
#                          'L_2': 0.004,
#                          'L_mot': 0.005,
#                          'L_vacuum': 0.003,
#                          'delta_vert_12': 0.001,
#                          'l_1': 0.001,
#                          'l_2': 0.01,
#                          'l_mot': 0.001,
#                          'l_vacuum': 0.001,
#                          'mesh_resolution': 100,
#                          'refine_mesh': True},
#             'particles_densities': [3.2e+19],
#             'particles_mean_number_per_cell': [50],
#             'particles_types': ['I'],
#             'phi': {'phi_bord_mot': 'N',
#                     'phi_electrode1': 100,
#                     'phi_electrode2': 300,
#                     'phi_inf_vacuum': 'N',
#                     'phi_inter_electrode': 'N',
#                     'phi_sup_vacuum': 'N',
#                     'phi_top_mot': '0',
#                     'rho_elec': 0.0},
#             'speed_param1': [0.0],
#             'speed_param2': [200.0],
#             'speed_type': ['uniform'],
#             'system_type': 'thruster',
#             'temperatures': [300]}}
# OrderedDict([('id_test', '1'),
#              ('path_to_data',
#               '/home/paul/Documents/projects/Neutralisation_Faisceau_ions_negatifs_propulsion_satellite/results/thruster_1/1.csv'),
#              ('number_of_collisions', '0'),
#              ('mean_acceptance_rate', '0'),
#              ('mean_proba', '0'),
#              ('mean_vr_norm', '0'),
#              ('nb_cells', '26'),
#              ('volume', '2.6000000000000005e-08'),
#              ('x_min', '0.0025'),
#              ('x_max', '0.0075'),
#              ('y_min', '0.013500000000000002'),
#              ('y_max', '0.027500000000000004'),
#              ('total_number_of_particles', '0'),
#              ('particles_types', 'I'),
#              ('particles_charges', '0'),
#              ('particles_masses', '2.35800283e-25'),
#              ('particles_effective_diameters', '4e-10'),
#              ('particles_densities', ('3.2e+19',)),
#              ('nb_parts_per_type', '1300'),
#              ('nb_parts_real_per_type', '832000000000'),
#              ('Ne_per_type', '640000000.0'),
#              ('mean_particles_number_per_cell_per_type', '50'),
#              ('min_mean_free_path', '0.043960757624858696'),
#              ('min_mean_free_time', '0.0002078578444279317'),
#              ('speed_init_type', 'uniform'),
#              ('v_mean', '211.49434001804408'),
#              ('vr_max_init', '422.98868003608817'),
#              ('vr_max_final', '0'),
#              ('dt', '5.196446110698293e-06'),
#              ('MAX_INTEGRATION_STEP', '500'),
#              ('integration_scheme', 'euler_explicit'),
#              ('saving_period', '5')])
#   0%|          | 0/500 [00:00<?, ?it/s]
# Iteration 0 : 133 particles.
#   1%|          | 5/500 [01:09<2:21:18, 17.13s/it]
# Iteration 5 : 792 particles.
#   2%|▏         | 10/500 [04:16<5:07:18, 37.63s/it]
# Iteration 10 : 1380 particles.
#   3%|▎         | 15/500 [09:08<7:43:58, 57.40s/it]
# Iteration 15 : 1899 particles.
#   4%|▍         | 20/500 [15:23<9:52:35, 74.07s/it]
# Iteration 20 : 2345 particles.
#   5%|▌         | 25/500 [22:52<11:38:05, 88.18s/it]
# Iteration 25 : 2707 particles.
#   6%|▌         | 30/500 [31:07<12:50:14, 98.33s/it]
# Iteration 30 : 3044 particles.
#   7%|▋         | 35/500 [40:16<14:07:48, 109.39s/it]
# Iteration 35 : 3375 particles.
#   8%|▊         | 40/500 [49:39<14:24:23, 112.75s/it]
# Iteration 40 : 3678 particles.
#   9%|▉         | 45/500 [59:47<15:17:25, 120.98s/it]
# Iteration 45 : 3924 particles.
#  10%|█         | 50/500 [1:10:41<16:16:41, 130.23s/it]
# Iteration 50 : 4179 particles.
#  11%|█         | 55/500 [1:22:27<17:29:55, 141.56s/it]
# Iteration 55 : 4327 particles.
#  12%|█▏        | 60/500 [1:35:25<18:47:06, 153.70s/it]
# Iteration 60 : 4508 particles.
#  13%|█▎        | 65/500 [1:49:15<20:01:48, 165.77s/it]
# Iteration 65 : 4697 particles.
#  14%|█▍        | 70/500 [2:03:31<20:24:01, 170.79s/it]
# Iteration 70 : 4871 particles.
#  14%|█▍        | 72/500 [2:09:19<20:28:10, 172.17s/it]
