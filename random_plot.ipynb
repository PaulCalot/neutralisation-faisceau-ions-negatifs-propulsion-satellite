# %%
import matplotlib.pyplot as plt
import matplotlib.ticker as mticker
import numpy as np

# %%
abscisse=[1,2,3,4]
ordonnee1=[0.22, 0.24, 0.45, 0.4]
ordonnee2=[0.03, 0.19, 0.32, 0.22]
avec_grille_cas_1=0

plt.figure(figsize=(10,10))
plt.scatter(abscisse, ordonnee2, color='k', label='Premier niveau de raffinement')
plt.scatter(abscisse, ordonnee1, color='orange', label='Second niveau de raffinement')
#plt.scatter(1, avec_grille_cas_1, color='red', label='Avec un 3ème grille, second niveau de raffinement')
plt.xlabel('N° du cas test', size=30)
plt.ylabel("Taux de neutralisation en sortie",size=30)
plt.legend(fontsize=13)
plt.ylim(-0.01,1)
plt.xticks([1, 2, 3, 4])
plt.tick_params(axis = 'both', labelsize = 20)

plt.show()
