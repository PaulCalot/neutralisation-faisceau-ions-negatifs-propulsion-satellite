# %% [markdown]
# # Testing saving and loading

# %%
from main import simulate, processing_only

system_cfg_path = 'cfg_files/test_loading/test_tube.cfg'
simulation_cfg_path = 'cfg_files/test_loading/simulation_tube_test.cfg'
processing_simulation_path = 'cfg_files/test_loading/processing_tube_test.cfg'

# %%
simulate(system_cfg_path, simulation_cfg_path, processing_simulation_path, verbose = False)
# Out:
# Launching simulation on square with 0 particles, at time 1.972711719974497e-05 s
# In grid number of particles 0
# 100%|██████████| 100/100 [00:01<00:00, 53.45it/s]
# Ending simulation on square with 529 particles, at time 0.0019924388371742392 s
# In grid number of particles 529

# %%
processing_only(system_cfg_path, simulation_cfg_path, processing_simulation_path, recompute = True)
# Out:
# Creating data analyser from /home/paul/Documents/projects/Neutralisation_Faisceau_ions_negatifs_propulsion_satellite/results/test_loading/params.csv...	[OK]
# Loading test 1...First time test 1 is loaded. Computing speed norm and saving it back.
# No handles with labels found to put in legend.
# Number of iterations : 100
# 	[OK]
# 	Compute selected frames...
# No handles with labels found to put in legend.
# No handles with labels found to put in legend.
# No handles with labels found to put in legend.
# 	[OK]
# 	Collisions...
# For test 1, N_e = 3.566222e+14 vs N_t = 1.600000e+15.
# [END COLLISIONS]
# 	Compute number of particles evolution...	[OK]

# %%
simulate(system_cfg_path, simulation_cfg_path, processing_simulation_path, load = True, verbose = False)
# Out:
# Launching simulation on square with 529 particles, at time 0.0019924388371742423 s
# In grid number of particles 529
# 100%|██████████| 100/100 [00:02<00:00, 38.11it/s]
# Ending simulation on square with 539 particles, at time 0.003965150557148733 s
# In grid number of particles 539

# %%
processing_only(system_cfg_path, simulation_cfg_path, processing_simulation_path, recompute = True)
# Out:
# Creating data analyser from /home/paul/Documents/projects/Neutralisation_Faisceau_ions_negatifs_propulsion_satellite/results/test_loading/params.csv...	[OK]
# Loading test 1...First time test 1 is loaded. Computing speed norm and saving it back.
# No handles with labels found to put in legend.
# Number of iterations : 200
# 	[OK]
# 	Compute selected frames...
# No handles with labels found to put in legend.
# No handles with labels found to put in legend.
# No handles with labels found to put in legend.
# 	[OK]
# 	Collisions...
# For test 1, N_e = 7.427556e+14 vs N_t = 3.200000e+15.
# [END COLLISIONS]
# 	Compute number of particles evolution...	[OK]
