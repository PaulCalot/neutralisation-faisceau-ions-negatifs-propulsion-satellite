# %%
from main import simulate, processing_only
# square
system_cfg_path = ['cfg_files/tests/test_tube.cfg']
simulation_cfg_path = ['cfg_files/tests/simulation_tube_test.cfg']
processing_simulation_path = ['cfg_files/tests/processing_tube_test.cfg']

for system, simu, proc in zip(system_cfg_path, simulation_cfg_path, processing_simulation_path):
    simulate(system, simu, proc)
# Out:
#   0%|          | 0/300 [00:00<?, ?it/s]
#   0%|          | 1/300 [00:00<00:51,  5.81it/s]
# Particles injected : [144], remainder : [0.33580099]
# Particles injected : [144], remainder : [0.67160197]
#   1%|          | 2/300 [00:00<01:03,  4.70it/s]
#   1%|          | 3/300 [00:00<01:06,  4.50it/s]
# Particles injected : [145], remainder : [0.00740296]
#   1%|▏         | 4/300 [00:00<01:11,  4.16it/s]
# Particles injected : [144], remainder : [0.34320395]
#   2%|▏         | 5/300 [00:04<07:17,  1.48s/it]
# Particles injected : [144], remainder : [0.67900493]
#   2%|▏         | 6/300 [00:04<05:17,  1.08s/it]
# Particles injected : [145], remainder : [0.01480592]
#   2%|▏         | 7/300 [00:25<36:29,  7.47s/it]
# Particles injected : [144], remainder : [0.35060691]
#   2%|▏         | 7/300 [01:00<41:56,  8.59s/it]
# ---------------------------------------------------------------------------
# KeyboardInterrupt                         Traceback (most recent call last)
# <ipython-input-1-882fc00dbe32> in <module>
#       6
#       7 for system, simu, proc in zip(system_cfg_path, simulation_cfg_path, processing_simulation_path):
# ----> 8     simulate(system, simu, proc)
#
# ~/Documents/projects/Neutralisation_Faisceau_ions_negatifs_propulsion_satellite/main/main.py in simulate(system_cfg_path, simulation_cfg_path, processing_cfg_path, verbose)
#      59     t = 0
#      60     for k in tqdm(range(MAX_INTEGRATION_STEP)): #
# ---> 61         system.step(dt, t)
#      62         t+=dt
#      63         list_particles = system.get_list_particles()
#
# ~/Documents/projects/Neutralisation_Faisceau_ions_negatifs_propulsion_satellite/main/builders/system.py in step(self, dt, t)
#     147
#     148     def step(self, dt, t):
# --> 149         self.dsmc.step(dt, t, self.f_args)
#     150         new_particles = self.flux_handler.step(dt)
#     151         if(self.debug):print('Injecting {} new particles.'.format(len(new_particles)))
#
# ~/Documents/projects/Neutralisation_Faisceau_ions_negatifs_propulsion_satellite/main/DSMC.py in step(self, dt, t, f_args)
#      80                 count += 1
#      81                 # then the particle got out of the box.
# ---> 82                 if not self._collision_with_wall(part):
#      83                     # in that case the particle exited the system by the wall
#      84                     # if a print message appears, then this was not suppoed to be the case
#
# ~/Documents/projects/Neutralisation_Faisceau_ions_negatifs_propulsion_satellite/main/DSMC.py in _collision_with_wall(self, part)
#     146         liste = []
#     147         for i in range(len(self.walls)):
# --> 148             t_coll, pos_intersect = self.handler_wall_collision(pos, -1.0*speed, radius, i)
#     149             liste.append((t_coll, pos_intersect, self.walls[i]))
#     150             if(t_coll<min_time):
#
# ~/Documents/projects/Neutralisation_Faisceau_ions_negatifs_propulsion_satellite/main/DSMC.py in handler_wall_collision(self, position, speed, radius, wall_indx)
#     219
#     220         # A and B
# --> 221         sTheta, cTheta = np.sin(theta), np.cos(theta)
#     222         B = -speed.x*sTheta+speed.y*cTheta
#     223         if B == 0.0 :
#
# KeyboardInterrupt:
